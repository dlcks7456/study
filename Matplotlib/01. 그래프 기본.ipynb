# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x00A28A90>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Tilte 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\CHAN_LEE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 방지

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'cmsy10',
#  'STIXNonUnicode',
#  'cmex10',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'cmtt10',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'cmb10',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeThreeSym',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmss10',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'Pyunji R',
#  'Goudy Old Style',
#  'Microsoft Sans Serif',
#  'Centaur',
#  'Franklin Gothic Demi Cond',
#  'MS Gothic',
#  'Gloucester MT Extra Condensed',
#  'Verdana',
#  'New Gulim',
#  'Tempus Sans ITC',
#  'Haan Sollip M',
#  'Sitka Small',
#  'Old English Text MT',
#  'Arial',
#  'Playbill',
#  'Times New Roman',
#  'Malgun Gothic',
#  'Candara',
#  'Garamond',
#  'Haansoft Batang',
#  'Courier10 BT',
#  'Gill Sans MT Condensed',
#  'Playbill',
#  'Palatino Linotype',
#  'OCR-A BT',
#  'Book Antiqua',
#  'Palace Script MT',
#  'Sylfaen',
#  'Perpetua',
#  'Palatino Linotype',
#  'Comic Sans MS',
#  'Berlin Sans FB',
#  'Lucida Bright',
#  'Microsoft Tai Le',
#  'Segoe UI Historic',
#  'Yj BACDOO Bold ',
#  'HYgprM',
#  'HYHeadLine-Medium',
#  'Century Gothic',
#  'Parchment',
#  'NanumGothic',
#  'Lucida Sans',
#  'Nirmala UI',
#  'Rockwell',
#  'Viner Hand ITC',
#  'Haan Baekje B',
#  'Yj BONMOKGAK Medium ',
#  'MDGaesung',
#  'MGungJeong',
#  'Californian FB',
#  'Franklin Gothic Heavy',
#  'Orator10 BT',
#  'Haan Cooljazz B',
#  'BernhardFashion BT',
#  'Candara',
#  'Calisto MT',
#  'HYdnkM',
#  'Lucida Fax',
#  'Arial',
#  'Juice ITC',
#  'Lucida Bright',
#  '210 MGothicOTF',
#  'Freestyle Script',
#  'Segoe UI',
#  'Pristina',
#  'Garamond',
#  'Ebrima',
#  'Bodoni Bd BT',
#  'Corbel',
#  'Consolas',
#  'Symbol',
#  'Haettenschweiler',
#  'HYnamB',
#  'SimSun-ExtB',
#  'Microsoft JhengHei',
#  'Tw Cen MT',
#  'Stencil',
#  'Cambria',
#  'MoeumT R',
#  'Informal Roman',
#  'Eras Medium ITC',
#  'Lucida Bright',
#  'Gigi',
#  'Segoe MDL2 Assets',
#  'Microsoft Sans Serif',
#  'Century Schoolbook',
#  'YJ BELLA Medium',
#  'Bookman Old Style',
#  'MDSol',
#  'Impact',
#  'Centaur',
#  'Calisto MT',
#  'Gadugi',
#  'Yj BACDOO Bold ',
#  'HYsanB',
#  'Sylfaen',
#  'HYGothic-Extra',
#  'Microsoft New Tai Lue',
#  '??????',
#  'Magic R',
#  'Yu Gothic',
#  'Berlin Sans FB Demi',
#  'Berlin Sans FB',
#  'Jokerman',
#  'GoudyOlSt BT',
#  'Chiller',
#  'Trebuchet MS',
#  'Yu Gothic',
#  'Matura MT Script Capitals',
#  'Times New Roman',
#  'Gill Sans MT Ext Condensed Bold',
#  'Malgun Gothic',
#  'Leelawadee UI',
#  'Haan Cooljazz B',
#  '???',
#  'Microsoft Tai Le',
#  'Calibri',
#  'MDArt',
#  'HCR Dotum',
#  'Cambria',
#  'Monotype Corsiva',
#  'Perpetua',
#  '??????',
#  'Showcard Gothic',
#  'HYmjrE',
#  'Tw Cen MT',
#  'Perpetua',
#  'Kunstler Script',
#  'FuturaBlack BT',
#  'MurrayHill Bd BT',
#  'Yet R',
#  'HYcysM',
#  'ahn2006-B',
#  'Eras Light ITC',
#  'Footlight MT Light',
#  'MDotum',
#  'Segoe UI',
#  'Tw Cen MT',
#  'Colonna MT',
#  'Stencil BT',
#  'CentSchbook BT',
#  'Blippo Blk BT',
#  'Niagara Engraved',
#  'HYsnrL',
#  'MV Boli',
#  'Script MT Bold',
#  'AmeriGarmnd BT',
#  'Haan Somang B',
#  '????',
#  'Bodoni Bk BT',
#  'Haan Sale B',
#  'Bodoni MT',
#  'Segoe UI',
#  'Haan Baekje M',
#  'HYnamM',
#  'MingLiU-ExtB',
#  'Microsoft JhengHei',
#  'Brush Script MT',
#  'CentSchbook BT',
#  'Rockwell',
#  'Sitka Small',
#  'Colonna MT',
#  'Myanmar Text',
#  'HCR Dotum',
#  'Calibri',
#  'Century Gothic',
#  'Haansoft Dotum',
#  'Century Schoolbook',
#  'Yj GOTGAE Medium',
#  'Tw Cen MT Condensed',
#  'Baskerville BT',
#  'CentSchbook BT',
#  'Haan YHead L',
#  'HYGungSo-Bold',
#  'Bradley Hand ITC',
#  'Century Gothic',
#  'Arial',
#  'Bookshelf Symbol 7',
#  'Gill Sans MT',
#  'Microsoft YaHei',
#  'Haan Cooljazz L',
#  'Trebuchet MS',
#  'Goudy Old Style',
#  'Calibri',
#  'SimSun',
#  'Leelawadee UI',
#  'MBatang',
#  'Segoe Script',
#  'Rockwell Condensed',
#  'Courier New',
#  'Maiandra GD',
#  'Calibri',
#  'Haan YHead M',
#  'Mongolian Baiti',
#  'Lucida Bright',
#  'Rockwell',
#  'Verdana',
#  'Gill Sans Ultra Bold Condensed',
#  'Georgia',
#  'Modern No. 20',
#  'Perpetua Titling MT',
#  'Lucida Sans Typewriter',
#  'Microsoft JhengHei',
#  'Meiryo',
#  'Century Gothic',
#  'Perpetua',
#  'BrushScript BT',
#  'Californian FB',
#  'Niagara Engraved',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Constantia',
#  'Gill Sans MT',
#  'MHunmin',
#  'MSugiHeulim',
#  'Freestyle Script',
#  'Dubai',
#  'Bauhaus 93',
#  'Magneto',
#  'Gabriola',
#  'Constantia',
#  'Copperplate Gothic Bold',
#  'Leelawadee',
#  'Gill Sans MT Ext Condensed Bold',
#  'MDEasop',
#  'Kristen ITC',
#  'Sitka Small',
#  'Arial',
#  'Neo Sans',
#  'Yj DOOLGI Medium',
#  'Snap ITC',
#  'V3Detect',
#  'Perpetua Titling MT',
#  'HYdnkM',
#  'Dubai',
#  'Lucida Sans',
#  'Agency FB',
#  'High Tower Text',
#  'MGungHeulim',
#  'MSugiHeulim',
#  'Newtext Bk BT',
#  '??????',
#  'Georgia',
#  'Eras Bold ITC',
#  'Lucida Fax',
#  'Poor Richard',
#  'HYmprL',
#  'OCR-A BT',
#  'Palatino Linotype',
#  'Javanese Text',
#  'Haettenschweiler',
#  'Nirmala UI',
#  'CommercialScript BT',
#  'Constantia',
#  'Calisto MT',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Times New Roman',
#  'Haan YGodic 250',
#  'Onyx',
#  'Segoe Print',
#  'MS Gothic',
#  'Lucida Bright',
#  'Kunstler Script',
#  'Cambria',
#  'GoudyOlSt BT',
#  'HYgtrE',
#  'Arial',
#  'Old English Text MT',
#  'Corbel',
#  'Bauhaus 93',
#  'HYMyeongJo-Extra',
#  'Microsoft New Tai Lue',
#  'Californian FB',
#  'Haan Baekje M',
#  'Candara',
#  'Yj SOSEL SemiBold',
#  'Goudy Old Style',
#  'Haan Sollip M',
#  'Vladimir Script',
#  'AmeriGarmnd BT',
#  'Engravers MT',
#  'Courier New',
#  'HYdnkB',
#  'Gill Sans Ultra Bold',
#  'Niagara Solid',
#  'Gill Sans MT',
#  'HCR Batang Ext',
#  'Gabriola',
#  'MJemokGothic',
#  'Arial',
#  'MDAlong',
#  'GoudyOlSt BT',
#  'Franklin Gothic Medium',
#  'Lucida Bright',
#  'Garamond',
#  'HYwulM',
#  'Segoe UI',
#  'FuturaBlack BT',
#  'Wingdings 3',
#  'Bodoni MT',
#  'Franklin Gothic Demi',
#  'Yet R',
#  'Haan YGodic 250',
#  'MGungJeong',
#  'Yj DOOLGI Medium',
#  'MBatang',
#  'Arial',
#  'Bodoni MT',
#  'Candara',
#  'Nirmala UI',
#  'Perpetua',
#  'Candara',
#  'Lucida Sans Unicode',
#  'Yj SHANALL Medium ',
#  'Blackadder ITC',
#  '??????',
#  'Wide Latin',
#  'Trebuchet MS',
#  'Felix Titling',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'AmeriGarmnd BT',
#  'Bookman Old Style',
#  'Segoe UI Symbol',
#  'Verdana',
#  'YJ INJANG Medium',
#  'HYtbrB',
#  'Stencil',
#  'Dubai',
#  'High Tower Text',
#  'OCR A Extended',
#  'BernhardFashion BT',
#  'Tw Cen MT',
#  'MDAlong',
#  'Bodoni MT',
#  'Haan Somang B',
#  'Matura MT Script Capitals',
#  'Lucida Handwriting',
#  'CommercialScript BT',
#  'Marlett',
#  '??????',
#  'HCR Batang',
#  'OCR-B-10 BT',
#  'MV Boli',
#  'Lucida Sans',
#  'Baskerville BT',
#  'Lucida Fax',
#  'HCR Dotum',
#  'HYbdaL',
#  'Segoe UI Symbol',
#  'Eras Bold ITC',
#  'Goudy Stout',
#  'Yu Gothic',
#  '??????',
#  'Courier New',
#  'CentSchbook BT',
#  'Franklin Gothic Demi',
#  'Corbel',
#  'Perpetua',
#  'Bernard MT Condensed',
#  'Bookshelf Symbol 7',
#  'Garamond',
#  'Bodoni MT',
#  'Freehand591 BT',
#  'HYtbrB',
#  'ParkAvenue BT',
#  'HCR Dotum Ext',
#  'Segoe UI',
#  'Goudy Stout',
#  'HCR Dotum',
#  '??????',
#  'Goudy Old Style',
#  'Bodoni Bk BT',
#  'Nirmala UI',
#  'Segoe Print',
#  'Yj TEUNTEUN Bold',
#  'Batang',
#  'Footlight MT Light',
#  'Myanmar Text',
#  'Microsoft Uighur',
#  'Segoe UI',
#  'Yj DWMMOOGJO',
#  'Agency FB',
#  'Segoe UI',
#  'BroadwayEngraved BT',
#  'Arial',
#  '210 MGothicOTF',
#  'Segoe UI Emoji',
#  'Franklin Gothic Demi',
#  'Calibri',
#  'FZSong_Superfont',
#  'Cooper Blk BT',
#  '? ??',
#  'Modern No. 20',
#  '??????',
#  'Lucida Sans Typewriter',
#  'Verdana',
#  '? ??',
#  'Lucida Console',
#  'Gill Sans Ultra Bold Condensed',
#  'HYGothic-Medium',
#  'Perpetua Titling MT',
#  'Bookman Old Style',
#  'Rockwell',
#  'Century Schoolbook',
#  'High Tower Text',
#  'Yj NANCHO Medium',
#  'Microsoft Yi Baiti',
#  'HYhaeseo',
#  '210 MGothicOTF',
#  'Microsoft Yi Baiti',
#  'Leelawadee',
#  'Franklin Gothic Demi Cond',
#  'Yj WADAG Medium',
#  'Copperplate Gothic Bold',
#  'MS Reference Specialty',
#  'HCR Batang',
#  'Calibri',
#  'HYGothic-Medium',
#  'Times New Roman',
#  'AmeriGarmnd BT',
#  'Arial',
#  'Leelawadee',
#  'Broadway',
#  'Leelawadee UI',
#  'Symbol',
#  'Cambria',
#  'Haan YGodic 240',
#  '??????',
#  'Yu Gothic',
#  '210 MGothic',
#  'ahn2006-B',
#  'Maiandra GD',
#  'MDArt',
#  'Lucida Console',
#  'Rockwell',
#  'Verdana',
#  'NanumGothic',
#  'GoudyOlSt BT',
#  'Lucida Sans Typewriter',
#  'Tahoma',
#  'Ink Free',
#  'MDGaesung',
#  '210 MGothicOTF',
#  'Bodoni Bk BT',
#  'V3Detect',
#  'Perpetua Titling MT',
#  'HYPost-Medium',
#  'Corbel',
#  'Elephant',
#  'Headline R',
#  'MSugiJeong',
#  'Microsoft Himalaya',
#  'Franklin Gothic Medium',
#  'Palatino Linotype',
#  'Haan YGodic 240',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'Trebuchet MS',
#  'MS Reference Sans Serif',
#  'HCR Dotum Ext',
#  'Haan Cooljazz M',
#  'Microsoft Uighur',
#  'GoudyOlSt BT',
#  'Blackadder ITC',
#  'Informal Roman',
#  'Wingdings 2',
#  'Microsoft Tai Le',
#  'Haan Cooljazz M',
#  'Goudy Old Style',
#  'Palace Script MT',
#  'Leelawadee UI',
#  'Nirmala UI',
#  'New Gulim',
#  'Swis721 BT',
#  'Lucida Sans Typewriter',
#  'Constantia',
#  'HYPMokGak-Bold',
#  'HYPost-Light',
#  'Harrington',
#  'Arial Rounded MT Bold',
#  'Lucida Sans',
#  '??????',
#  'HYporM',
#  'HYbdaM',
#  'Georgia',
#  'Segoe UI',
#  'Bodoni MT',
#  'Malgun Gothic',
#  'Consolas',
#  'Tw Cen MT',
#  'Californian FB',
#  'Wingdings 3',
#  'HYwulM',
#  'CentSchbook BT',
#  'Segoe UI',
#  'Lucida Fax',
#  'Courier New',
#  '210 MGothicOTF',
#  'DomCasual BT',
#  'OCR-B-10 BT',
#  'Rockwell Extra Bold',
#  'Lucida Calligraphy',
#  'Microsoft New Tai Lue',
#  'Microsoft YaHei',
#  'Comic Sans MS',
#  'Arial Unicode MS',
#  'Palatino Linotype',
#  'Bell MT',
#  'Yj TEUNTEUN Bold',
#  'Haan Somang M',
#  'Segoe UI',
#  '210 MGothic',
#  'HYPMokGak-Bold',
#  'ahn2006-M',
#  'Candara',
#  'Tempus Sans ITC',
#  'Cooper Black',
#  'Yj DWMMOOGJO',
#  'Lucida Bright',
#  'ahn2006-M',
#  'Courier10 BT',
#  'Bell MT',
#  'HYShortSamul-Medium',
#  '????',
#  'Ebrima',
#  'Leelawadee UI',
#  'Cambria',
#  'Rockwell Condensed',
#  'Haansoft Batang',
#  'Imprint MT Shadow',
#  'Tw Cen MT',
#  'Bookman Old Style',
#  'Segoe UI',
#  'Arial',
#  'Segoe UI',
#  'Segoe UI',
#  'Castellar',
#  'Garamond',
#  'Haan YHead M',
#  'Dubai',
#  'Tw Cen MT Condensed',
#  'HYGungSo-Bold',
#  'HYbsrB',
#  'Segoe MDL2 Assets',
#  'Hobo BT',
#  'Goudy Old Style',
#  'OCR A Extended',
#  'Corbel',
#  'Perpetua',
#  'Gill Sans MT',
#  'High Tower Text',
#  'Yj INITIALPOSITIVE Medium',
#  'Magneto',
#  'HYnamL',
#  'Eras Demi ITC',
#  'Yj INITIALPOSITIVE Medium',
#  'Leelawadee',
#  'Calibri',
#  'Elephant',
#  'MS Outlook',
#  'CentSchbook BT',
#  'Arial',
#  'Arial',
#  'Corbel',
#  'MDSol',
#  'Lucida Sans',
#  'Cambria',
#  'Microsoft Tai Le',
#  'Haan Somang M',
#  'Century Schoolbook',
#  'Liberty BT',
#  'BrushScript BT',
#  'Copperplate Gothic Light',
#  'Segoe UI',
#  'Georgia',
#  'Haan Baekje B',
#  'Script MT Bold',
#  'Yj SHANALL Medium ',
#  'Franklin Gothic Book',
#  'MJemokBatang',
#  'Baskerville Old Face',
#  'Harrington',
#  'Vivaldi',
#  'Franklin Gothic Book',
#  'Cambria',
#  'Mongolian Baiti',
#  'Rockwell Condensed',
#  'HYgprM',
#  'Bodoni MT',
#  'Blippo Blk BT',
#  'Edwardian Script ITC',
#  'Chiller',
#  'Webdings',
#  'Britannic Bold',
#  'Lucida Fax',
#  'Cooper Blk BT',
#  'Trebuchet MS',
#  'Consolas',
#  'Corbel',
#  'Bell MT',
#  'Calibri',
#  'Candara',
#  'AmeriGarmnd BT',
#  'HYnamM',
#  'TeamViewer14',
#  'HYgtrE',
#  'Rockwell Condensed',
#  'MJemokBatang',
#  'Gadugi',
#  'Franklin Gothic Medium',
#  'HYGothic-Extra',
#  'Imprint MT Shadow',
#  'MSugiJeong',
#  'Microsoft PhagsPa',
#  'Segoe Script',
#  'Trebuchet MS',
#  'Times New Roman',
#  'Candara',
#  'Berlin Sans FB Demi',
#  'YJ BELLA Medium',
#  'Trebuchet MS',
#  'Gadugi',
#  'Microsoft Uighur',
#  'HCR Batang Ext',
#  'HoloLens MDL2 Assets',
#  'Ravie',
#  'Segoe UI',
#  'Tw Cen MT Condensed Extra Bold',
#  '????',
#  'Candara',
#  'Palatino Linotype',
#  'Meiryo',
#  'Consolas',
#  'Dubai',
#  'Segoe UI',
#  'Haan Cooljazz L',
#  'Baskerville Old Face',
#  'Consolas',
#  'Book Antiqua',
#  'Wide Latin',
#  'Yj BONMOKGAK Medium ',
#  'Microsoft PhagsPa',
#  'Bodoni MT',
#  'Gill Sans MT',
#  'Book Antiqua',
#  'Calisto MT',
#  'Rage Italic',
#  'MS Reference Specialty',
#  'Garamond',
#  'Algerian',
#  'Calisto MT',
#  'Swis721 BT',
#  'Meiryo',
#  'GoudyOlSt BT',
#  'Haan YHead B',
#  'Segoe Script',
#  'Comic Sans MS',
#  'Gill Sans MT Condensed',
#  'Felix Titling',
#  'HYsupB',
#  'HYdnkB',
#  'Microsoft YaHei',
#  'Dubai',
#  'Segoe UI',
#  'Lucida Bright',
#  'Lucida Fax',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'Elephant',
#  'Franklin Gothic Medium',
#  'Ami R',
#  'Courier10 BT',
#  'Segoe UI',
#  'Gadugi',
#  'Corbel',
#  'MGungHeulim',
#  'Haan Sale B',
#  'Magic R',
#  'Calibri',
#  'GoudyOlSt BT',
#  'Gill Sans Ultra Bold',
#  'Agency FB',
#  'Constantia',
#  'Rockwell',
#  'HYGraphic-Medium',
#  'Franklin Gothic Medium Cond',
#  'Cooper Blk BT',
#  'Broadway',
#  'Lucida Sans',
#  'Yj BLOCK Medium',
#  'Comic Sans MS',
#  'HYHeadLine-Medium',
#  'Arial',
#  'Book Antiqua',
#  'Constantia',
#  'Parchment',
#  'MJemokGothic',
#  'Verdana',
#  'BroadwayEngraved BT',
#  'Eras Medium ITC',
#  'Lucida Sans',
#  'Franklin Gothic Heavy',
#  'Papyrus',
#  'Impact',
#  'Tahoma',
#  'Consolas',
#  'Lucida Sans',
#  'Calisto MT',
#  'MDEasop',
#  'Rockwell',
#  'CentSchbook BT',
#  'FZSong_Superfont',
#  'Haan Sollip B',
#  'Georgia',
#  'Century Gothic',
#  'Arial',
#  'HYsupB',
#  'AmeriGarmnd BT',
#  'Elephant',
#  'Bodoni Bk BT',
#  'HYporM',
#  'HYGraphic-Medium',
#  'Swis721 BT',
#  'Bell MT',
#  'Yj BUTGOT Light ',
#  'Malgun Gothic',
#  'Curlz MT',
#  'Californian FB',
#  'Dubai',
#  'Sitka Small',
#  'Ink Free',
#  '????',
#  'Lucida Bright',
#  '????',
#  'Century Schoolbook',
#  'Agency FB',
#  'HYcysM',
#  'Yu Gothic',
#  'Calibri',
#  'Sitka Small',
#  'Segoe UI',
#  'Myanmar Text',
#  'Times New Roman',
#  'Webdings',
#  'French Script MT',
#  'Arial',
#  'Kristen ITC',
#  'Calisto MT',
#  '???',
#  'Corbel',
#  'HYSinMyeongJo-Medium',
#  'HYsupM',
#  'HYbdaM',
#  'Tw Cen MT Condensed Extra Bold',
#  'Sitka Small',
#  'Pristina',
#  'Harlow Solid Italic',
#  'Bell MT',
#  'HYPost-Light',
#  'Yj CHMSOOT Bold',
#  'Headline R',
#  'Pyunji R',
#  'MS Outlook',
#  'Engravers MT',
#  'Franklin Gothic Book',
#  'Yj MAEHWA  SemiBold',
#  'Palatino Linotype',
#  'Meiryo',
#  'Book Antiqua',
#  'Segoe UI',
#  'Segoe UI',
#  'Bodoni MT',
#  'Yj WADAG Medium',
#  'Rage Italic',
#  'Gloucester MT Extra Condensed',
#  'Lucida Handwriting',
#  'Sitka Small',
#  'Snap ITC',
#  'Franklin Gothic Heavy',
#  'Calibri',
#  'Batang',
#  'Gulim',
#  'Lucida Sans',
#  'Microsoft Uighur',
#  'Leelawadee UI',
#  'Comic Sans MS',
#  'Corbel',
#  'Yj GABI',
#  'Viner Hand ITC',
#  'Algerian',
#  'HYkanM',
#  'Calisto MT',
#  'Malgun Gothic',
#  'Gill Sans MT',
#  'Century Schoolbook',
#  '210 MGothicOTF',
#  'Comic Sans MS',
#  'Wingdings',
#  'Tw Cen MT',
#  'Bodoni MT',
#  'MT Extra',
#  'Onyx',
#  'Ami R',
#  'Arial Unicode MS',
#  '??????',
#  'Yj GABI',
#  'DomCasual BT',
#  'Bodoni MT',
#  'Palatino Linotype',
#  'Bodoni MT',
#  'Wingdings',
#  'HYkanB',
#  'Bookman Old Style',
#  'Arial',
#  'Calibri',
#  'Lucida Fax',
#  'Swis721 BT',
#  'Edwardian Script ITC',
#  'MHunmin',
#  'SimSun-ExtB',
#  'Century Gothic',
#  'Consolas',
#  'Bodoni MT',
#  'Lucida Bright',
#  'Candara',
#  'Monotype Corsiva',
#  'Segoe UI Historic',
#  'Bodoni MT',
#  'Microsoft New Tai Lue',
#  'Californian FB',
#  'Eras Light ITC',
#  'Arial',
#  'Lucida Sans',
#  'HyhwpEQ',
#  'MDotum',
#  'HYsnrL',
#  'Berlin Sans FB',
#  'ahn2006-L',
#  'YJ INJANG Medium',
#  'HYnamL',
#  'Courier New',
#  'Bradley Hand ITC',
#  'Verdana',
#  'Bahnschrift',
#  'Juice ITC',
#  'Candara',
#  'Book Antiqua',
#  'Microsoft Himalaya',
#  '??????',
#  'Courier New',
#  'Yj CHMSOOT Bold',
#  'Yu Gothic',
#  'Gill Sans MT',
#  'Rockwell Extra Bold',
#  'Century Gothic',
#  'Trebuchet MS',
#  'Consolas',
#  '??????',
#  'Castellar',
#  'Yj MAEHWA  SemiBold',
#  'Dubai',
#  'Hobo BT',
#  'Corbel',
#  'HyhwpEQ',
#  'Segoe UI',
#  'Niagara Solid',
#  'Franklin Gothic Book',
#  'Brush Script MT',
#  'HYsupM',
#  'Bodoni Bd BT',
#  'Javanese Text',
#  'Vivaldi',
#  '??????',
#  'Poor Richard',
#  'Orator10 BT',
#  'Bernard MT Condensed',
#  'Wingdings 2',
#  'Century',
#  'MS Reference Sans Serif',
#  'Orbit-B BT',
#  'Yj SOSEL SemiBold',
#  'Jokerman',
#  'Bodoni MT',
#  'Tahoma',
#  'Franklin Gothic Medium Cond',
#  'Yu Gothic',
#  'Candara',
#  'Rockwell',
#  'SimSun',
#  'HYhaeseo',
#  'Curlz MT',
#  'Bahnschrift',
#  'Yj BLOCK Medium',
#  'Cambria',
#  'Gill Sans MT',
#  'Bodoni MT',
#  'HYgsrB',
#  'Vladimir Script',
#  'TeamViewer14',
#  'Book Antiqua',
#  'HYkanM',
#  'Georgia',
#  'Papyrus',
#  'Cooper Black',
#  'Verdana',
#  'Haan YHead B',
#  '????',
#  'CentSchbook BT',
#  'HYPost-Medium',
#  'Georgia',
#  'Tw Cen MT Condensed',
#  'Malgun Gothic',
#  'Yj GOTGAE Medium',
#  '??????',
#  'Tahoma',
#  'Times New Roman',
#  'Haan Sale M',
#  'HYSinMyeongJo-Medium',
#  'Bell MT',
#  'Harlow Solid Italic',
#  'HYkanB',
#  'ParkAvenue BT',
#  'HYwulB',
#  'Haan YGodic 230',
#  'Haan YGodic 230',
#  'Ravie',
#  'Microsoft JhengHei',
#  'Tw Cen MT Condensed',
#  'Lucida Fax',
#  'Copperplate Gothic Light',
#  'Segoe Print',
#  'HYsanB',
#  'Arial',
#  'Neo Sans',
#  'Lucida Sans Unicode',
#  'Lucida Sans Typewriter',
#  'Segoe UI',
#  'Gulim',
#  'HYgsrB',
#  'Gigi',
#  'MingLiU-ExtB',
#  'Perpetua',
#  'MurrayHill Bd BT',
#  'MoeumT R',
#  'Courier10 BT',
#  'Constantia',
#  'Microsoft JhengHei',
#  'Bodoni Bd BT',
#  'Newtext Bk BT',
#  'Haan Sale M',
#  'AmeriGarmnd BT',
#  'Georgia',
#  'Yj NANCHO Medium',
#  'French Script MT',
#  'Ebrima',
#  'HYbdaL',
#  'Microsoft YaHei',
#  '210 MGothic',
#  ...]

# %%
plt.plot(x, y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
plt.show()
